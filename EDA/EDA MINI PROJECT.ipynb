# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fifa = pd.read_csv('fifa.csv')
fifa_info = pd.read_csv('fifa_ variable_information.csv')

# %% [markdown]
# # 1. Import the necessary libraries and read the data.

# %%
fifa.head()
# Out:
#        ID               Name  Age  \
# 0  158023           L. Messi   31
# 1   20801  Cristiano Ronaldo   33
# 2  190871          Neymar Jr   26
# 3  193080             De Gea   27
# 4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# 4   https://cdn.sofifa.org/flags/7.png       91         92
#
#                   Club                                     Club Logo  ...  \
# 0         FC Barcelona  https://cdn.sofifa.org/teams/2/light/241.png  ...
# 1             Juventus   https://cdn.sofifa.org/teams/2/light/45.png  ...
# 2  Paris Saint-Germain   https://cdn.sofifa.org/teams/2/light/73.png  ...
# 3    Manchester United   https://cdn.sofifa.org/teams/2/light/11.png  ...
# 4      Manchester City   https://cdn.sofifa.org/teams/2/light/10.png  ...
#
#   Composure Marking StandingTackle  SlidingTackle  GKDiving  GKHandling  \
# 0      96.0    33.0           28.0           26.0       6.0        11.0
# 1      95.0    28.0           31.0           23.0       7.0        11.0
# 2      94.0    27.0           24.0           33.0       9.0         9.0
# 3      68.0    15.0           21.0           13.0      90.0        85.0
# 4      88.0    68.0           58.0           51.0      15.0        13.0
#
#   GKKicking GKPositioning GKReflexes  Release Clause
# 0      15.0          14.0        8.0         €226.5M
# 1      15.0          14.0       11.0         €127.1M
# 2      15.0          15.0       11.0         €228.1M
# 3      87.0          88.0       94.0         €138.6M
# 4       5.0          10.0       13.0         €196.4M
#
# [5 rows x 60 columns]

# %%
fifa_info.head()
# Out:
#             ID     unique id for every player
# 0         Name                           name
# 1          Age                            age
# 2        Photo      url to the player's photo
# 3  Nationality                    nationality
# 4         Flag  url to players's country flag

# %%
fifa.isnull().sum()
# Out:
# ID                              0
# Name                            0
# Age                             0
# Photo                           0
# Nationality                     0
# Flag                            0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Body Type                      48
# Position                       60
# Jersey Number                  60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# Crossing                       48
# Finishing                      48
# HeadingAccuracy                48
# ShortPassing                   48
# Volleys                        48
# Dribbling                      48
# Curve                          48
# FKAccuracy                     48
# LongPassing                    48
# BallControl                    48
# Acceleration                   48
# SprintSpeed                    48
# Agility                        48
# Reactions                      48
# Balance                        48
# ShotPower                      48
# Jumping                        48
# Stamina                        48
# Strength                       48
# LongShots                      48
# Aggression                     48
# Interceptions                  48
# Positioning                    48
# Vision                         48
# Penalties                      48
# Composure                      48
# Marking                        48
# StandingTackle                 48
# SlidingTackle                  48
# GKDiving                       48
# GKHandling                     48
# GKKicking                      48
# GKPositioning                  48
# GKReflexes                     48
# Release Clause               1564
# dtype: int64

# %%
fifa.describe()
# Out:
#                   ID           Age       Overall     Potential  \
# count   18207.000000  18207.000000  18207.000000  18207.000000
# mean   214298.338606     25.122206     66.238699     71.307299
# std     29965.244204      4.669943      6.908930      6.136496
# min        16.000000     16.000000     46.000000     48.000000
# 25%    200315.500000     21.000000     62.000000     67.000000
# 50%    221759.000000     25.000000     66.000000     71.000000
# 75%    236529.500000     28.000000     71.000000     75.000000
# max    246620.000000     45.000000     94.000000     95.000000
#
#        International Reputation     Weak Foot   Skill Moves  Jersey Number  \
# count              18159.000000  18159.000000  18159.000000   18147.000000
# mean                   1.113222      2.947299      2.361308      19.546096
# std                    0.394031      0.660456      0.756164      15.947765
# min                    1.000000      1.000000      1.000000       1.000000
# 25%                    1.000000      3.000000      2.000000       8.000000
# 50%                    1.000000      3.000000      2.000000      17.000000
# 75%                    1.000000      3.000000      3.000000      26.000000
# max                    5.000000      5.000000      5.000000      99.000000
#
#            Crossing     Finishing  ...     Penalties     Composure  \
# count  18159.000000  18159.000000  ...  18159.000000  18159.000000
# mean      49.734181     45.550911  ...     48.548598     58.648274
# std       18.364524     19.525820  ...     15.704053     11.436133
# min        5.000000      2.000000  ...      5.000000      3.000000
# 25%       38.000000     30.000000  ...     39.000000     51.000000
# 50%       54.000000     49.000000  ...     49.000000     60.000000
# 75%       64.000000     62.000000  ...     60.000000     67.000000
# max       93.000000     95.000000  ...     92.000000     96.000000
#
#             Marking  StandingTackle  SlidingTackle      GKDiving  \
# count  18159.000000    18159.000000   18159.000000  18159.000000
# mean      47.281623       47.697836      45.661435     16.616223
# std       19.904397       21.664004      21.289135     17.695349
# min        3.000000        2.000000       3.000000      1.000000
# 25%       30.000000       27.000000      24.000000      8.000000
# 50%       53.000000       55.000000      52.000000     11.000000
# 75%       64.000000       66.000000      64.000000     14.000000
# max       94.000000       93.000000      91.000000     90.000000
#
#          GKHandling     GKKicking  GKPositioning    GKReflexes
# count  18159.000000  18159.000000   18159.000000  18159.000000
# mean      16.391596     16.232061      16.388898     16.710887
# std       16.906900     16.502864      17.034669     17.955119
# min        1.000000      1.000000       1.000000      1.000000
# 25%        8.000000      8.000000       8.000000      8.000000
# 50%       11.000000     11.000000      11.000000     11.000000
# 75%       14.000000     14.000000      14.000000     14.000000
# max       92.000000     91.000000      90.000000     94.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# # 2.	Drop any columns that you deem unecessary for analysis.

# %%
fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall',
#        'Potential', 'Club', 'Club Logo', 'Value', 'Wage', 'Preferred Foot',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Work Rate',
#        'Body Type', 'Position', 'Jersey Number', 'Joined', 'Loaned From',
#        'Contract Valid Until', 'Height', 'Weight', 'Crossing', 'Finishing',
#        'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
#        'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
#        'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
#        'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
#        'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
#        'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
#        'GKKicking', 'GKPositioning', 'GKReflexes', 'Release Clause'],
#       dtype='object')

# %%
# the columns dropped are found to have no impact on the selection criteria of the player i.e. flag, logos, individual rating as overall rating is available.
# the columns remaining are believed to be useful for further evaluation

# %%
fifa.drop(['Flag','Nationality','Photo','Body Type','Jersey Number','Crossing', 'Finishing',
       'HeadingAccuracy', 'ShortPassing', 'Volleys', 'Dribbling', 'Curve',
       'FKAccuracy', 'LongPassing', 'BallControl', 'Acceleration',
       'SprintSpeed', 'Agility', 'Reactions', 'Balance', 'ShotPower',
       'Jumping', 'Stamina', 'Strength', 'LongShots', 'Aggression',
       'Interceptions', 'Positioning', 'Vision', 'Penalties', 'Composure',
       'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving', 'GKHandling',
       'GKKicking', 'GKPositioning', 'GKReflexes'],axis = 1,inplace = True)

# %%
fifa.columns
# Out:
# Index(['ID', 'Name', 'Age', 'Overall', 'Potential', 'Club', 'Club Logo',
#        'Value', 'Wage', 'Preferred Foot', 'International Reputation',
#        'Weak Foot', 'Skill Moves', 'Work Rate', 'Position', 'Joined',
#        'Loaned From', 'Contract Valid Until', 'Height', 'Weight',
#        'Release Clause'],
#       dtype='object')

# %%
fifa.isnull().sum()
# loaned from column has almost 94% of values as null values 
#hence its of no use as any imputation made will make the data biased
# so it can be dropped
# Out:
# ID                              0
# Name                            0
# Age                             0
# Overall                         0
# Potential                       0
# Club                          241
# Club Logo                       0
# Value                           0
# Wage                            0
# Preferred Foot                 48
# International Reputation       48
# Weak Foot                      48
# Skill Moves                    48
# Work Rate                      48
# Position                       60
# Joined                       1553
# Loaned From                 16943
# Contract Valid Until          289
# Height                         48
# Weight                         48
# Release Clause               1564
# dtype: int64

# %%
fifa.drop('Loaned From',axis = 1,inplace = True)
fifa
# Out:
#            ID                Name  Age  Overall  Potential  \
# 0      158023            L. Messi   31       94         94
# 1       20801   Cristiano Ronaldo   33       94         94
# 2      190871           Neymar Jr   26       92         93
# 3      193080              De Gea   27       91         93
# 4      192985        K. De Bruyne   27       91         92
# ...       ...                 ...  ...      ...        ...
# 18202  238813        J. Lundstram   19       47         65
# 18203  243165  N. Christoffersson   19       47         63
# 18204  241638           B. Worman   16       47         67
# 18205  246268      D. Walker-Rice   17       47         66
# 18206  246269           G. Nugent   16       46         66
#
#                       Club                                       Club Logo  \
# 0             FC Barcelona    https://cdn.sofifa.org/teams/2/light/241.png
# 1                 Juventus     https://cdn.sofifa.org/teams/2/light/45.png
# 2      Paris Saint-Germain     https://cdn.sofifa.org/teams/2/light/73.png
# 3        Manchester United     https://cdn.sofifa.org/teams/2/light/11.png
# 4          Manchester City     https://cdn.sofifa.org/teams/2/light/10.png
# ...                    ...                                             ...
# 18202      Crewe Alexandra    https://cdn.sofifa.org/teams/2/light/121.png
# 18203       Trelleborgs FF    https://cdn.sofifa.org/teams/2/light/703.png
# 18204     Cambridge United   https://cdn.sofifa.org/teams/2/light/1944.png
# 18205      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
# 18206      Tranmere Rovers  https://cdn.sofifa.org/teams/2/light/15048.png
#
#          Value   Wage Preferred Foot  International Reputation  Weak Foot  \
# 0      €110.5M  €565K           Left                       5.0        4.0
# 1         €77M  €405K          Right                       5.0        4.0
# 2      €118.5M  €290K          Right                       5.0        5.0
# 3         €72M  €260K          Right                       4.0        3.0
# 4        €102M  €355K          Right                       4.0        5.0
# ...        ...    ...            ...                       ...        ...
# 18202     €60K    €1K          Right                       1.0        2.0
# 18203     €60K    €1K          Right                       1.0        2.0
# 18204     €60K    €1K          Right                       1.0        3.0
# 18205     €60K    €1K          Right                       1.0        3.0
# 18206     €60K    €1K          Right                       1.0        3.0
#
#        Skill Moves       Work Rate Position        Joined  \
# 0              4.0  Medium/ Medium       RF   Jul 1, 2004
# 1              5.0       High/ Low       ST  Jul 10, 2018
# 2              5.0    High/ Medium       LW   Aug 3, 2017
# 3              1.0  Medium/ Medium       GK   Jul 1, 2011
# 4              4.0      High/ High      RCM  Aug 30, 2015
# ...            ...             ...      ...           ...
# 18202          2.0  Medium/ Medium       CM   May 3, 2017
# 18203          2.0  Medium/ Medium       ST  Mar 19, 2018
# 18204          2.0  Medium/ Medium       ST   Jul 1, 2017
# 18205          2.0  Medium/ Medium       RW  Apr 24, 2018
# 18206          2.0  Medium/ Medium       CM  Oct 30, 2018
#
#       Contract Valid Until Height  Weight Release Clause
# 0                     2021    5'7  159lbs        €226.5M
# 1                     2022    6'2  183lbs        €127.1M
# 2                     2022    5'9  150lbs        €228.1M
# 3                     2020    6'4  168lbs        €138.6M
# 4                     2023   5'11  154lbs        €196.4M
# ...                    ...    ...     ...            ...
# 18202                 2019    5'9  134lbs          €143K
# 18203                 2020    6'3  170lbs          €113K
# 18204                 2021    5'8  148lbs          €165K
# 18205                 2019   5'10  154lbs          €143K
# 18206                 2019   5'10  176lbs          €165K
#
# [18207 rows x 20 columns]

# %% [markdown]
# # datatype conversions

# %%
# value column concersion after removing the necessary symbols and letters

# %%
fifa['Value']=fifa['Value'].str.replace('€','')
fifa['Value']=fifa['Value'].str.replace('K','000')
fifa['Value']=fifa['Value'].str.replace('M','000000')

# %%
fifa.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Overall                       int64
# Potential                     int64
# Club                         object
# Club Logo                    object
# Value                        object
# Wage                         object
# Preferred Foot               object
# International Reputation    float64
# Weak Foot                   float64
# Skill Moves                 float64
# Work Rate                    object
# Position                     object
# Joined                       object
# Contract Valid Until         object
# Height                       object
# Weight                       object
# Release Clause               object
# dtype: object

# %%
# value column from object to float conversion
fifa['Value'] = fifa['Value'].astype('float')

# %%
fifa.dtypes
# Out:
# ID                            int64
# Name                         object
# Age                           int64
# Overall                       int64
# Potential                     int64
# Club                         object
# Club Logo                    object
# Value                       float64
# Wage                         object
# Preferred Foot               object
# International Reputation    float64
# Weak Foot                   float64
# Skill Moves                 float64
# Work Rate                    object
# Position                     object
# Joined                       object
# Contract Valid Until         object
# Height                       object
# Weight                       object
# Release Clause               object
# dtype: object

# %%
# 'Wage' conversion to float

# %%
fifa['Wage']=fifa['Wage'].str.replace('€','')
fifa['Wage']=fifa['Wage'].str.replace('K','000')
fifa['Wage']=fifa['Wage'].str.replace('M','000000')

# %%
fifa['Wage'] = fifa['Wage'].astype('float')

# %%
fifa['Wage'].dtype
# Out:
# dtype('float64')

# %%
# 'Joined' conversion

# %%
fifa['Joined']=pd.DatetimeIndex(fifa['Joined']).year
fifa['Joined']
# Out:
# 0        2004.0
# 1        2018.0
# 2        2017.0
# 3        2011.0
# 4        2015.0
#           ...
# 18202    2017.0
# 18203    2018.0
# 18204    2017.0
# 18205    2018.0
# 18206    2018.0
# Name: Joined, Length: 18207, dtype: float64

# %%
fifa['Joined']= fifa['Joined'].astype('float')

# %%
fifa['Joined'].dtype
# Out:
# dtype('float64')

# %%
# 'Contract Valid Until' conversion from string to float

# %%
fifa['Contract Valid Until'].dtype
# Out:
# dtype('O')

# %%
fifa['Contract Valid Until'] = pd.to_datetime(fifa['Contract Valid Until'])

# %%
fifa['Contract Valid Until']
# Out:
# 0       2021-01-01
# 1       2022-01-01
# 2       2022-01-01
# 3       2020-01-01
# 4       2023-01-01
#            ...
# 18202   2019-01-01
# 18203   2020-01-01
# 18204   2021-01-01
# 18205   2019-01-01
# 18206   2019-01-01
# Name: Contract Valid Until, Length: 18207, dtype: datetime64[ns]

# %%
# 'Height' conversion to float by replacing ' with .'

# %%
fifa['Height'].dtype
# Out:
# dtype('O')

# %%
fifa['Height']
# Out:
# 0         5'7
# 1         6'2
# 2         5'9
# 3         6'4
# 4        5'11
#          ...
# 18202     5'9
# 18203     6'3
# 18204     5'8
# 18205    5'10
# 18206    5'10
# Name: Height, Length: 18207, dtype: object

# %%
fifa['Height']=fifa['Height'].str.replace("'",".")

# %%
fifa['Height']=fifa['Height'].astype("float")
print(fifa['Height'].dtype)
fifa['Height']
# Out:
# float64
# 0        5.70
# 1        6.20
# 2        5.90
# 3        6.40
# 4        5.11
#          ...
# 18202    5.90
# 18203    6.30
# 18204    5.80
# 18205    5.10
# 18206    5.10
# Name: Height, Length: 18207, dtype: float64

# %%
# weight conversion with required changes
fifa['Weight']=fifa['Weight'].str.replace("lbs","")
fifa['Weight']=fifa['Weight'].astype("float")

# %%
fifa['Weight'].dtype
# Out:
# dtype('float64')

# %%
# release cause conversion
fifa['Release Clause']
# Out:
# 0        €226.5M
# 1        €127.1M
# 2        €228.1M
# 3        €138.6M
# 4        €196.4M
#           ...
# 18202      €143K
# 18203      €113K
# 18204      €165K
# 18205      €143K
# 18206      €165K
# Name: Release Clause, Length: 18207, dtype: object

# %%
fifa['Release Clause']=fifa['Release Clause'].str.replace('€','')
fifa['Release Clause']=fifa['Release Clause'].str.replace('K','1000')
fifa['Release Clause']=fifa['Release Clause'].str.replace('M','1000000')
fifa['Release Clause']=fifa['Release Clause'].astype("float")

# %%
print(fifa['Release Clause'].dtype)
fifa['Release Clause']
# Out:
# float64
# 0            226.51
# 1            127.11
# 2            228.11
# 3            138.61
# 4            196.41
#             ...
# 18202    1431000.00
# 18203    1131000.00
# 18204    1651000.00
# 18205    1431000.00
# 18206    1651000.00
# Name: Release Clause, Length: 18207, dtype: float64

# %% [markdown]
# # 4.	Check for missing values and do a mean imputation where necessary.

# %%
fifa.isnull().sum()/len(fifa) * 100
# Out:
# ID                          0.000000
# Name                        0.000000
# Age                         0.000000
# Overall                     0.000000
# Potential                   0.000000
# Club                        1.323667
# Club Logo                   0.000000
# Value                       0.000000
# Wage                        0.000000
# Preferred Foot              0.263635
# International Reputation    0.263635
# Weak Foot                   0.263635
# Skill Moves                 0.263635
# Work Rate                   0.263635
# Position                    0.329544
# Joined                      8.529686
# Contract Valid Until        1.587302
# Height                      0.263635
# Weight                      0.263635
# Release Clause              8.590103
# dtype: float64

# %%
# release_cause, joined,contract_valid_untill have numerical missing values in range of 1-10 % 
# replacing missing values wouldnt change the distribution as percent is less
# yet we are proceeding with missing values imputation using mean imputation

# %%
fifa['Release Clause'].describe()
# since the percentage is less there qouldnt be any effect of imputation on the distribution which can be observed from below plots
# Out:
# count    1.664300e+04
# mean     7.006385e+06
# std      3.627655e+07
# min      1.110000e+00
# 25%      3.110000e+00
# 50%      9.410000e+05
# 75%      5.461000e+06
# max      1.641000e+09
# Name: Release Clause, dtype: float64

# %%
sns.distplot(fifa['Release Clause'])
# Out:
# C:\Users\Sekhar\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Release Clause', ylabel='Density'>

# %%
fifa['Release Clause'].fillna(fifa['Release Clause'].mean(),inplace = True)

# %%
sns.distplot(fifa['Release Clause'])
# Out:
# C:\Users\Sekhar\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Release Clause', ylabel='Density'>

# %%
sns.distplot(fifa['Joined'])
# Out:
# C:\Users\Sekhar\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Joined', ylabel='Density'>

# %%
print(round(fifa['Joined'].mean()))
print(fifa['Joined'].median())
# there isnt much difference between mean and median hence replacing with mean wouldnt effect the distribution
# Out:
# 2016
# 2017.0

# %%
fifa['Joined'].fillna(round(fifa['Joined'].mean()),inplace = True)

# %%
sns.distplot(fifa['Joined'])
# Out:
# C:\Users\Sekhar\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Joined', ylabel='Density'>

# %% [markdown]
# # Exploratory Analysis:

# %% [markdown]
# # 1.	Plot the distribution of Overall rating for all players.

# %%
sns.distplot(fifa['Overall'])
# Out:
# C:\Users\Sekhar\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Overall', ylabel='Density'>

# %%
# it can be observed that the distribution is almost normal,there are no players in range of 68-70 rating 
# also the mean and median are pretty much close to each other which is a property of normal distribution
print(fifa['Overall'].mean())
print(fifa['Overall'].median())
# Out:
# 66.23869940132916
# 66.0

# %%
# also there are no null values which implies the distribution is for all datas available i.e. 100%
fifa['Overall'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # pairplots for  Overall, Value, Wage, International Reputation, Height, Weight, Release Clause

# %%
sns.pairplot(fifa[['Overall', 'Value', 'Wage', 'International Reputation', 'Height', 'Weight', 'Release Clause']])

# %% [markdown]
# # 3.	Generate a table containing the top 20 players ranked by Overall score and whose contract expires in 2020.

# %%
top_20 = fifa.loc[:,['Name','Age','Overall','Value','Wage','Contract Valid Until']]
top_20 = top_20[top_20['Contract Valid Until'] == '2020-01-01']

# %%
top_20 = top_20.sort_values(by = 'Overall',ascending=False).head(20)
top_20
# Out:
#                 Name  Age  Overall       Value      Wage Contract Valid Until
# 3             De Gea   27       91  72000000.0  260000.0           2020-01-01
# 6          L. Modrić   32       91  67000000.0  420000.0           2020-01-01
# 8       Sergio Ramos   32       91  51000000.0  380000.0           2020-01-01
# 5          E. Hazard   27       91  93000000.0  340000.0           2020-01-01
# 13       David Silva   32       90  60000000.0  285000.0           2020-01-01
# 21         E. Cavani   31       89  60000000.0  200000.0           2020-01-01
# 24      G. Chiellini   33       89  27000000.0  215000.0           2020-01-01
# 31        C. Eriksen   26       88        73.5  205000.0           2020-01-01
# 39      Thiago Silva   33       88  24000000.0  165000.0           2020-01-01
# 50        D. Mertens   31       87  45000000.0  135000.0           2020-01-01
# 52         M. Hamšík   30       87        46.5  125000.0           2020-01-01
# 49        Jordi Alba   29       87  38000000.0  250000.0           2020-01-01
# 46          K. Navas   31       87        30.5  195000.0           2020-01-01
# 64       Alex Sandro   27       86        36.5  160000.0           2020-01-01
# 71   T. Alderweireld   29       86  39000000.0  150000.0           2020-01-01
# 73        M. Benatia   31       86  30000000.0  160000.0           2020-01-01
# 75       Fernandinho   33       86  18000000.0  185000.0           2020-01-01
# 102            Naldo   35       85   9000000.0   38000.0           2020-01-01
# 104          Miranda   33       85        15.5   96000.0           2020-01-01
# 103       B. Matuidi   31       85  26000000.0  145000.0           2020-01-01

# %%
# Average wage for top 20 players
top_20['Wage'].mean()
# Out:
# 205450.0

# %%
# Average age for top 20 players
top_20['Age'].mean()
# Out:
# 30.65

# %%
# correlation between wage and value of top 20 players
fifa[['Overall','Value']].corr()
# the correplation can be inferred as moderate positive relation as the value is being close to +0.5
# the positive sign indicated a positive relation and the value indicated the strength as moderate positive
# Out:
#           Overall     Value
# Overall  1.000000  0.394758
# Value    0.394758  1.000000

# %% [markdown]
# # 4.	Generate tables containing the top 5 players by Overall rating for each unique position.

# %%
top_5 = fifa.loc[:,['ID','Name','Age','Overall','Value','Wage','Position']]
#top_5['Position'] = top_5['Position'].fillna(top_5['Position'].mode(),inplace = True)

# %%
top_5.sort_values(by = ['Position','Overall'],ascending= False)
# Out:
#            ID               Name  Age  Overall       Value      Wage Position
# 1       20801  Cristiano Ronaldo   33       94  77000000.0  405000.0       ST
# 10     188545     R. Lewandowski   29       90  77000000.0  205000.0       ST
# 16     202126            H. Kane   24       89        83.5  205000.0       ST
# 23     153079          S. Agüero   30       89        64.5  300000.0       ST
# 36     173731            G. Bale   28       88  60000000.0  355000.0       ST
# ...       ...                ...  ...      ...         ...       ...      ...
# 16793  228192         E. Lyngdoh   31       56         0.0       0.0      NaN
# 17129  228198           J. Singh   26       55         0.0       0.0      NaN
# 17339  233526           S. Passi   23       54         0.0       0.0      NaN
# 17436  236452     D. Lalhlimpuia   20       54         0.0       0.0      NaN
# 17539  234508           C. Singh   21       53         0.0       0.0      NaN
#
# [18207 rows x 7 columns]

# %%
top_5['Position'].fillna(top_5['Position'].mode(),inplace = True)

# %%
top_5_new = pd.DataFrame(top_5.groupby('Position')['Overall','Name'].tail(5))
# Out:
# C:\Users\sai krishna\AppData\Local\Temp\ipykernel_1400\74698506.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   top_5_new = pd.DataFrame(top_5.groupby('Position')['Overall','Name'].tail(5))

# %%
for i in top_5['Position'].unique():
    print(top_5[top_5['Position'] == i][['Overall','Name','Position','Wage']].head())
# Out:
#       Overall         Name Position      Wage
# 0          94     L. Messi       RF  565000.0
# 50         87   D. Mertens       RF  135000.0
# 528        80    D. Valeri       RF   12000.0
# 890        78  L. Podolski       RF   11000.0
# 1774       75     C. Ciano       RF   17000.0
#     Overall               Name Position      Wage
# 1        94  Cristiano Ronaldo       ST  405000.0
# 10       90     R. Lewandowski       ST  205000.0
# 16       89            H. Kane       ST  205000.0
# 23       89          S. Agüero       ST  300000.0
# 36       88            G. Bale       ST  355000.0
#     Overall        Name Position      Wage
# 2        92   Neymar Jr       LW  290000.0
# 29       88  L. Insigne       LW  165000.0
# 30       88        Isco       LW  315000.0
# 32       88    Coutinho       LW  340000.0
# 55       86     L. Sané       LW  195000.0
#     Overall           Name Position      Wage
# 3        91         De Gea       GK  260000.0
# 9        90       J. Oblak       GK   94000.0
# 18       89  M. ter Stegen       GK  240000.0
# 19       89    T. Courtois       GK  240000.0
# 22       89       M. Neuer       GK  130000.0
#     Overall          Name Position      Wage
# 4        91  K. De Bruyne      RCM  355000.0
# 6        91     L. Modrić      RCM  420000.0
# 53       87    I. Rakitić      RCM  260000.0
# 82       85    J. Kimmich      RCM   92000.0
# 83       85          Saúl      RCM   77000.0
#       Overall            Name Position      Wage
# 5          91       E. Hazard       LF  340000.0
# 15         89       P. Dybala       LF  205000.0
# 76         86         Iniesta       LF   21000.0
# 272        82  Jonathan Viera       LF   31000.0
# 1379       76       S. Blanco       LF    9000.0
#      Overall            Name Position      Wage
# 7         91       L. Suárez       RS  455000.0
# 109       85  Z. Ibrahimović       RS   15000.0
# 148       84          Falcao       RS  115000.0
# 267       82   W. Ben Yedder       RS   28000.0
# 357       81         S. Zaza       RS   48000.0
#     Overall          Name Position      Wage
# 8        91  Sergio Ramos      RCB  380000.0
# 39       88  Thiago Silva      RCB  165000.0
# 54       87         Piqué      RCB  240000.0
# 62       86     R. Varane      RCB  210000.0
# 70       86    L. Bonucci      RCB  160000.0
#      Overall             Name Position      Wage
# 11        90         T. Kroos      LCM  355000.0
# 13        90      David Silva      LCM  285000.0
# 52        87        M. Hamšík      LCM  125000.0
# 63        86      M. Verratti      LCM  135000.0
# 114       84  Bruno Fernandes      LCM   22000.0
#      Overall         Name Position      Wage
# 12        90     D. Godín       CB  125000.0
# 42        87    S. Umtiti       CB  205000.0
# 73        86   M. Benatia       CB  160000.0
# 89        85  N. Otamendi       CB  170000.0
# 102       85        Naldo       CB   38000.0
#      Overall         Name Position      Wage
# 14        89     N. Kanté      LDM  225000.0
# 91        85     Paulinho      LDM  235000.0
# 119       84   Marquinhos      LDM   90000.0
# 217       83  Lucas Leiva      LDM   64000.0
# 323       81   F. de Jong      LDM   19000.0
#     Overall             Name Position      Wage
# 17       89     A. Griezmann      CAM  145000.0
# 31       88       C. Eriksen      CAM  205000.0
# 61       86  Roberto Firmino      CAM  195000.0
# 66       86        T. Müller      CAM  135000.0
# 74       86          M. Özil      CAM  190000.0
#      Overall             Name Position      Wage
# 20        89  Sergio Busquets      CDM  315000.0
# 27        88         Casemiro      CDM  285000.0
# 72        86        M. Pjanić      CDM  180000.0
# 75        86      Fernandinho      CDM  185000.0
# 118       84          Fabinho      CDM  120000.0
#      Overall           Name Position      Wage
# 21        89      E. Cavani       LS  200000.0
# 38        88     G. Higuaín       LS  245000.0
# 100       85    Diego Costa       LS  100000.0
# 151       84       A. Gómez       LS   53000.0
# 174       83  Gerard Moreno       LS   53000.0
#     Overall           Name Position      Wage
# 24       89   G. Chiellini      LCB  215000.0
# 34       88     M. Hummels      LCB  160000.0
# 44       87   K. Koulibaly      LCB  115000.0
# 51       87  J. Vertonghen      LCB  155000.0
# 59       86    V. van Dijk      LCB  165000.0
#      Overall           Name Position      Wage
# 25        88      K. Mbappé       RM  100000.0
# 26        88       M. Salah       RM  255000.0
# 122       84     F. Thauvin       RM   72000.0
# 137       84  José Callejón       RM  105000.0
# 138       84    A. Di María       RM  125000.0
#       Overall             Name Position      Wage
# 28         88     J. Rodríguez      LAM  315000.0
# 365        81         D. Tadić      LAM   26000.0
# 1587       75   Fabrio Farinha      LAM   31000.0
# 2247       74  Leo Caldeirinha      LAM   13000.0
# 2342       74  Nicolás Formido      LAM   23000.0
#     Overall           Name Position      Wage
# 33       88  P. Aubameyang       LM  265000.0
# 58       86        S. Mané       LM  195000.0
# 65       86  Douglas Costa       LM  175000.0
# 68       86        M. Reus       LM  100000.0
# 86       85           Koke       LM   88000.0
#      Overall         Name Position      Wage
# 35        88      Marcelo       LB  285000.0
# 49        87   Jordi Alba       LB  250000.0
# 64        86  Alex Sandro       LB  160000.0
# 85        85     D. Alaba       LB  110000.0
# 106       85  Filipe Luís       LB   81000.0
#      Overall          Name Position      Wage
# 45        87      P. Pogba      RDM  210000.0
# 134       84  Illarramendi      RDM   51000.0
# 198       83      I. Gueye      RDM  125000.0
# 223       83   D. De Rossi      RDM   80000.0
# 298       82     M. Parolo      RDM   59000.0
#     Overall            Name Position      Wage
# 56       86  Bernardo Silva       RW  180000.0
# 60       86     R. Sterling       RW  195000.0
# 79       85   Marco Asensio       RW  215000.0
# 84       85       R. Mahrez       RW  205000.0
# 93       85      A. Sánchez       RW  215000.0
#      Overall                 Name Position      Wage
# 67        86               Thiago       CM  130000.0
# 78        85  S. Milinković-Savić       CM   73000.0
# 121       84             Jorginho       CM  155000.0
# 136       84          I. Gündoğan       CM  175000.0
# 161       83             N. Keïta       CM  120000.0
#      Overall           Name Position      Wage
# 69        86    Azpilicueta       RB  175000.0
# 123       84       Carvajal       RB  185000.0
# 135       84      K. Walker       RB  165000.0
# 192       83  Sergi Roberto       RB  170000.0
# 216       83      L. Bender       RB   82000.0
#       Overall            Name Position      Wage
# 129        84     J. Cuadrado      RAM  150000.0
# 171        83       H. Ziyech      RAM   28000.0
# 1705       75  Allan Bardinho      RAM   22000.0
# 2242       74    Jacson Zonta      RAM   13000.0
# 2322       74  Sebas Couteira      RAM   14000.0
#      Overall          Name Position     Wage
# 271       82  Luis Alberto       CF  67000.0
# 293       82   S. Giovinco       CF  15000.0
# 350       81      A. Milik       CF  71000.0
# 382       81     L. Stindl       CF  43000.0
# 407       81       Raffael       CF  41000.0
#      Overall          Name Position     Wage
# 450       80     M. Ginter      RWB  28000.0
# 465       80  P. Kadeřábek      RWB  39000.0
# 517       80    S. Coleman      RWB  97000.0
# 652       79  D. Caligiuri      RWB  33000.0
# 766       78  Pablo Maffeo      RWB  24000.0
#      Overall       Name Position     Wage
# 474       80  N. Schulz      LWB  37000.0
# 581       79    Granell      LWB  37000.0
# 601       79      Jonny      LWB  43000.0
# 605       79  J. Hector      LWB  26000.0
# 787       78  J. Mojica      LWB  28000.0
# Empty DataFrame
# Columns: [Overall, Name, Position, Wage]
# Index: []

# %%
for i in top_5['Position'].unique():
    x = top_5[top_5['Position'] == i]['Wage'].head().mean()
    print('average wage of top 5 in ',i,'=',x)
# Out:
# average wage of top 5 in  RF = 148000.0
# average wage of top 5 in  ST = 294000.0
# average wage of top 5 in  LW = 261000.0
# average wage of top 5 in  GK = 192800.0
# average wage of top 5 in  RCM = 240800.0
# average wage of top 5 in  LF = 121200.0
# average wage of top 5 in  RS = 132200.0
# average wage of top 5 in  RCB = 231000.0
# average wage of top 5 in  LCM = 184400.0
# average wage of top 5 in  CB = 139600.0
# average wage of top 5 in  LDM = 126600.0
# average wage of top 5 in  CAM = 174000.0
# average wage of top 5 in  CDM = 217000.0
# average wage of top 5 in  LS = 130200.0
# average wage of top 5 in  LCB = 162000.0
# average wage of top 5 in  RM = 131400.0
# average wage of top 5 in  LAM = 81600.0
# average wage of top 5 in  LM = 164600.0
# average wage of top 5 in  LB = 177200.0
# average wage of top 5 in  RDM = 105000.0
# average wage of top 5 in  RW = 202000.0
# average wage of top 5 in  CM = 130600.0
# average wage of top 5 in  RB = 155400.0
# average wage of top 5 in  RAM = 45400.0
# average wage of top 5 in  CF = 47400.0
# average wage of top 5 in  RWB = 44200.0
# average wage of top 5 in  LWB = 34200.0
# average wage of top 5 in  nan = nan

# %%
top_5['Name']
# Out:
# Age         18207
# Overall     18207
# Value       18207
# Wage        18207
# Position    18147
# dtype: int64

# %%
# Are there any players appearing in more than one Table. Please point out such players.
top_5['ID'].duplicated().sum()
# Out:
# 0
